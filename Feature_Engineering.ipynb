# %% [markdown]
# ### Import Libraries

# %%
import re
import time
import logging 
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime
from geopy.geocoders import Nominatim, GoogleV3

# %% [markdown]
# ### Read & Load Data

# %%
df = pd.read_csv("Rental_data.csv")

# %% [markdown]
# ### Extracting Full Address, Latitude, Longitude

# %%
# Replace elements in the "address" column before run the geolocator
df['address'] = df['address'].str.replace(r'\bLor\b', 'Lorong', regex=True)
df['address'] = df['address'].str.replace(r'\bNth\b', 'North', regex=True)
df['address'] = df['address'].str.replace(r'\bBt\b', 'Bukit', regex=True)
df['address'] = df['address'].str.replace(r'\bUpp\b', 'Upper', regex=True)
df['address'] = df['address'].str.replace(r'\bTg\b', 'Tanjong', regex=True)

# %%
# Start the timer
start_time = time.time()

# Initialize Nominatim geocoder 
geolocator = Nominatim(user_agent="james", timeout=10)

# Function to get full address, latitude, longitude
def geocode_and_get_details(address):
    location = geolocator.geocode(address + ",Singapore")
    if location:
        lat, lon = location.latitude, location.longitude
        full_address = location.address
        print(f"Geocoded: {address} -> Latitude: {lat}, Longitude: {lon}")
        return full_address, lat, lon
    else:
        logging.warning(f"Failed to geocode: {address}")
        return None, None, None  # Return defaults if geocoding fails

# Apply the combined function to the DataFrame
df['full_address'], df['latitude'], df['longitude'] = zip(*df['address'].apply(geocode_and_get_details))

# End the timer
end_time = time.time()
elapsed_time = end_time - start_time
# Out:
# Geocoded: 508A Wellington Circle -> Latitude: 1.4525175, Longitude: 103.82036918981923
# Geocoded: 32 Woodlands Cres -> Latitude: 1.4454434, Longitude: 103.80637936318752
# Geocoded: 424C Yishun Avenue 11 -> Latitude: 1.423389, Longitude: 103.8461491
# Geocoded: 808A Chai Chee Road -> Latitude: 1.3269912499999998, Longitude: 103.92403088745593
# Geocoded: 36 Margaret Drive -> Latitude: 1.29747565, Longitude: 103.80539723690086
# Geocoded: 101 Pasir Ris Street 12 -> Latitude: 1.367117, Longitude: 103.95809213010453
# Geocoded: 31 Marsiling Drive -> Latitude: 1.4430507499999998, Longitude: 103.7723239884499
# Geocoded: 3 Tay Lian Teck Rd -> Latitude: 1.3133793, Longitude: 103.9295903
# Geocoded: 330 Serangoon Avenue 3 -> Latitude: 1.3500410999999999, Longitude: 103.86946626069472
# Geocoded: Perak Road -> Latitude: 1.3049925, Longitude: 103.8535853
# Geocoded: 312 Woodlands Street 31 -> Latitude: 1.4306985, Longitude: 103.77565629761565
# Geocoded: 6 Marina Boulevard -> Latitude: 1.277909, Longitude: 103.8586195
# Geocoded: 23 Fernvale Lane -> Latitude: 1.3902012, Longitude: 103.8736121
# Geocoded: 17 Fernvale Lane -> Latitude: 1.3902012, Longitude: 103.8736121
# Geocoded: 38 Lorong Ong Lye -> Latitude: 1.34944805, Longitude: 103.87921705
# Geocoded: 1 Lorong 20 Geylang -> Latitude: 1.31237995, Longitude: 103.88150541871565
# Geocoded: 11 Jln Mutiara -> Latitude: 1.2954753, Longitude: 103.8282793
# Geocoded: 34 Woodlands Dr 16 -> Latitude: 1.4326975499999999, Longitude: 103.79979345032189
# Geocoded: 150 Mariam Way -> Latitude: 1.3589568, Longitude: 103.9697391
# Geocoded: 722 Tampines Street 72 -> Latitude: 1.3599499, Longitude: 103.93566906000001
# Geocoded: 6 Marina Boulevard -> Latitude: 1.277909, Longitude: 103.8586195
# Geocoded: 35 Jurong East Ave 1 -> Latitude: 1.3438892999999998, Longitude: 103.73406270022355
# Geocoded: 902 Sims Ave -> Latitude: 1.3185148500000001, Longitude: 103.90384943030031
# Geocoded: 642C Punggol Drive -> Latitude: 1.3985658, Longitude: 103.91595525622091
# Geocoded: 8 Sing Joo Walk -> Latitude: 1.3152237, Longitude: 103.8553206
# Geocoded: 449 Choa Chu Kang Avenue 4 -> Latitude: 1.3791581, Longitude: 103.7363220101308
# Geocoded: 420 Canberra Road -> Latitude: 1.4525754499999999, Longitude: 103.81858943101153
# Geocoded: 11 Eunos Crescent -> Latitude: 1.32181425, Longitude: 103.90445540754678
# Geocoded: 11 Eunos Crescent -> Latitude: 1.32181425, Longitude: 103.90445540754678
# Geocoded: 810 Geylang Rd -> Latitude: 1.3149932, Longitude: 103.8936825
# Geocoded: 484C Choa Chu Kang Avenue 5 -> Latitude: 1.3755913, Longitude: 103.73705601811437
# Geocoded: 22 Boon Keng Road -> Latitude: 1.3190438, Longitude: 103.8617815
# Geocoded: 417 Jurong West Street 42 -> Latitude: 1.3512453, Longitude: 103.72700060559
# Geocoded: 2 Hougang St 92 -> Latitude: 1.3741175, Longitude: 103.8783599621737
# Geocoded: 332 Jln Eunos -> Latitude: 1.3247369, Longitude: 103.9055414
# WARNING:root:Failed to geocode: 690F Woodlands Drive 75
# Geocoded: 1 North Bridge Rd -> Latitude: 1.29006055, Longitude: 103.84908795439796
# Geocoded: 963A Upper Changi Rd North -> Latitude: 1.3602733, Longitude: 103.970309
# Geocoded: 97 Geylang Bahru -> Latitude: 1.3237417, Longitude: 103.87024856757391
# Geocoded: 774 Pasir Ris Street 71 -> Latitude: 1.3742298000000002, Longitude: 103.93669867682132
# Geocoded: 2 Upper Aljunied Lane -> Latitude: 1.3340013499999999, Longitude: 103.87897045
# Geocoded: 1C Cantonment Road -> Latitude: 1.27743925, Longitude: 103.84166719999999
# Geocoded: 389 Yishun Avenue 6 -> Latitude: 1.422224, Longitude: 103.8500985
# Geocoded: 5 Simei St 3 -> Latitude: 1.3442406, Longitude: 103.956037
# Geocoded: 327 Ang Mo Kio Avenue 2 -> Latitude: 1.3765525, Longitude: 103.834698
# Geocoded: 217B Boon Lay Avenue -> Latitude: 1.3497001499999999, Longitude: 103.7107780035539
# Geocoded: 31 Hougang Ave 7 -> Latitude: 1.36843255, Longitude: 103.8993041517531
# Geocoded: 10 Upper Serangoon View -> Latitude: 1.3767755, Longitude: 103.9037883

# %%
print(f"Geocoding process took {elapsed_time:.2f} seconds")
# Out:
# Geocoding process took 3802.63 seconds

# %%
# Initialize Google Geocoder
api_key = 'AIzaSyBvuUbJevwEF4sQl1jKd78C1MJSk89PxCA'
google_geolocator = GoogleV3(api_key=api_key)

# Create a function to geocode addresses using Google Geocoding API
def geocode_with_google(address):
    try:
        location_g = google_geolocator.geocode(address + ", Singapore")
        if location_g:
            lat, lon = location_g.latitude, location_g.longitude
            full_address = location_g.address
            print(f"Geocoded (Google): {address} -> Latitude: {lat}, Longitude: {lon}")
            return full_address, lat, lon
        else:
            print(f"Google Geocoding API couldn't find a result for: {address}")
            return None, None, None
    except Exception as e:
        print(f"Error during Google Geocoding: {str(e)}")
        return None, None, None

remaining_df = df.loc[df['full_address'].isnull()]
# Apply the Google Geocoding function to the remaining DataFrame
remaining_df['full_address_google'], remaining_df['latitude_google'], remaining_df['longitude_google'] = zip(*remaining_df['address'].apply(geocode_with_google))

# Define a condition for rows where 'full_address' is null
condition = df['full_address'].isnull()

# Assign the values from remaining_df to df based on the condition
df.loc[condition, 'latitude'] = remaining_df['latitude_google'].values
df.loc[condition, 'longitude'] = remaining_df['longitude_google'].values
# Out:
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Gerald Mugliston Estate -> Latitude: 1.3857547, Longitude: 103.876156
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Macpherson Garden Estate -> Latitude: 1.3321561, Longitude: 103.8803716
# Geocoded (Google): Frankel Estate -> Latitude: 1.316494, Longitude: 103.917948
# Geocoded (Google): Davisville -> Latitude: 1.352083, Longitude: 103.819836
# Geocoded (Google): Seletar Garden -> Latitude: 1.3907521, Longitude: 103.8508873
# Geocoded (Google): 689B Woodlands Drive 75 -> Latitude: 1.4445799, Longitude: 103.8083586
# Geocoded (Google): 687A Woodlands Drive 75 -> Latitude: 1.4410632, Longitude: 103.8072719
# Geocoded (Google): Fuyong Estate -> Latitude: 1.358096, Longitude: 103.768433
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Yong Seng Estate -> Latitude: 1.325648, Longitude: 103.916852
# Geocoded (Google): Sembawang Hills Estate -> Latitude: 1.3732162, Longitude: 103.8301171
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Yong Seng Estate -> Latitude: 1.325648, Longitude: 103.916852
# Geocoded (Google): Dunman Regency -> Latitude: 1.3095638, Longitude: 103.893429
# Geocoded (Google): Loyang Villas -> Latitude: 1.3694459, Longitude: 103.9694014
# Geocoded (Google): Loyang Villas -> Latitude: 1.3694459, Longitude: 103.9694014
# Geocoded (Google): Apollo Gardens -> Latitude: 1.3379125, Longitude: 103.9581086
# Geocoded (Google): 690C Woodlands Drive 75 -> Latitude: 1.4429678, Longitude: 103.8079058
# Geocoded (Google): Kembangan Villas -> Latitude: 1.3246966, Longitude: 103.9143958
# Geocoded (Google): Tai Peng Gardens -> Latitude: 1.3625425, Longitude: 103.8891116
# Geocoded (Google): Tai Peng Gardens -> Latitude: 1.3625425, Longitude: 103.8891116
# Geocoded (Google): Tivoli Gardens -> Latitude: 1.352083, Longitude: 103.819836
# Geocoded (Google): Blair Plain Conservation Area -> Latitude: 1.2762933, Longitude: 103.8363264
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Bournemouth Eight -> Latitude: 1.3016299, Longitude: 103.8914698
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Golden Shower Park -> Latitude: 1.352083, Longitude: 103.819836
# Geocoded (Google): Springleaf Villas -> Latitude: 1.3999593, Longitude: 103.8237915
# Geocoded (Google): Villa Verde -> Latitude: 1.3915287, Longitude: 103.7518063
# Geocoded (Google): Fuyong Estate -> Latitude: 1.358096, Longitude: 103.768433
# Geocoded (Google): Mandai Garden -> Latitude: 1.403182, Longitude: 103.812567
# Geocoded (Google): Florence Grove -> Latitude: 1.3623648, Longitude: 103.8859364
# Geocoded (Google): Lowland View -> Latitude: 1.361151, Longitude: 103.8832573
# Geocoded (Google): Loyang Villas -> Latitude: 1.3694459, Longitude: 103.9694014
# Geocoded (Google): Mayflower Gardens -> Latitude: 1.371738, Longitude: 103.83948
# Geocoded (Google): Hillview Garden Estate -> Latitude: 1.3576165, Longitude: 103.7583548
# Geocoded (Google): Kembangan Estate -> Latitude: 1.3246966, Longitude: 103.9143958
# Geocoded (Google): 690D Woodlands Drive 75 -> Latitude: 1.4426008, Longitude: 103.8079058
# Geocoded (Google): 690D Woodlands Drive 75 -> Latitude: 1.4426008, Longitude: 103.8079058
# Geocoded (Google): Kew Lodge -> Latitude: 1.327917, Longitude: 103.82075
# Geocoded (Google): Lucky Hill -> Latitude: 1.2745295, Longitude: 103.8259281
# Geocoded (Google): Tanglin Hill Condominium -> Latitude: 1.3017079, Longitude: 103.8162015
# Geocoded (Google): Tai Peng Gardens -> Latitude: 1.3625425, Longitude: 103.8891116
# Geocoded (Google): Tai Peng Gardens -> Latitude: 1.3625425, Longitude: 103.8891116
# Geocoded (Google): Sembawang Straits Estate -> Latitude: 1.4504191, Longitude: 103.8285321
# Geocoded (Google): Cashew Villas -> Latitude: 1.3714454, Longitude: 103.7694594
# Geocoded (Google): Petain Road/Tyrwhitt Road Conservation Area -> Latitude: 1.3108543, Longitude: 103.8596446
# Geocoded (Google): Geylang Conservation Area -> Latitude: 1.3200544, Longitude: 103.8917746
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Serangoon Garden Estate -> Latitude: 1.3639688, Longitude: 103.8658082
# Geocoded (Google): Seaside Park -> Latitude: 1.352083, Longitude: 103.819836
# Geocoded (Google): Sembawang Straits Estate -> Latitude: 1.4504191, Longitude: 103.8285321
# Geocoded (Google): Tembeling Lodge -> Latitude: 1.3139803, Longitude: 103.9011028
# Geocoded (Google): Mayflower Gardens -> Latitude: 1.371738, Longitude: 103.83948
# Geocoded (Google): Fuyong Estate -> Latitude: 1.358096, Longitude: 103.768433
py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remaining_df['full_address_google'], remaining_df['latitude_google'], remaining_df['longitude_google'] = zip(*remaining_df['address'].apply(geocode_with_google))
# /var/folders/xz/j7j5wcrx00jbk3d3s9tr3z2r0000gn/T/ipykernel_24470/2969337530.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remaining_df['full_address_google'], remaining_df['latitude_google'], remaining_df['longitude_google'] = zip(*remaining_df['address'].apply(geocode_with_google))
# /var/folders/xz/j7j5wcrx00jbk3d3s9tr3z2r0000gn/T/ipykernel_24470/2969337530.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remaining_df['full_address_google'], remaining_df['latitude_google'], remaining_df['longitude_google'] = zip(*remaining_df['address'].apply(geocode_with_google))

# %%
# Clean the full_address_google by removing the postal code
remaining_df['full_address_google'] = remaining_df['full_address_google'].str.split(',').str[0].str.strip()

# Apply the geocode_and_get_details function to the remaining_df
geocoded_results = remaining_df['full_address_google'].apply(geocode_and_get_details)

# Extract the full address part from tuples in 'geocoded_results'
geocoded_addresses = geocoded_results.apply(lambda x: x[0] if isinstance(x, tuple) else x)

# Update the DataFrame using .loc with the condition
df.loc[condition, 'full_address'] = geocoded_addresses
# Out:
# /var/folders/xz/j7j5wcrx00jbk3d3s9tr3z2r0000gn/T/ipykernel_24470/4278968704.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remaining_df['full_address_google'] = remaining_df['full_address_google'].str.split(',').str[0].str.strip()
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: 34 Jln Kechubong -> Latitude: 1.38561325, Longitude: 103.8761442235026
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: 72 Jln Gembira -> Latitude: 1.3320764, Longitude: 103.8796611
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 122 Cactus Rd -> Latitude: 1.3910267, Longitude: 103.8514797
# WARNING:root:Failed to geocode: 689B Woodlands Drive 75
# WARNING:root:Failed to geocode: 687A Woodlands Drive 75
# WARNING:root:Failed to geocode: Singapore 678762
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: 18L Jln Paras -> Latitude: 1.32547195, Longitude: 103.91662945
# Geocoded: 8 Jln Gelenggang -> Latitude: 1.3730794, Longitude: 103.8301189658496
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: 18L Jln Paras -> Latitude: 1.32547195, Longitude: 103.91662945
# Geocoded: 485 Dunman Rd -> Latitude: 1.3096473999999998, Longitude: 103.89339
# Geocoded: Loyang -> Latitude: 1.3753678, Longitude: 103.9772924
# Geocoded: Loyang -> Latitude: 1.3753678, Longitude: 103.9772924
# Geocoded: 585A Upper Changi Rd -> Latitude: 1.3347016, Longitude: 103.9513927
# WARNING:root:Failed to geocode: 690C Woodlands Drive 75
# Geocoded: Taman Kembangan -> Latitude: 1.3245794, Longitude: 103.9136468
# Geocoded: 15 Jln Rengkam -> Latitude: 1.3624478, Longitude: 103.888377
# Geocoded: 15 Jln Rengkam -> Latitude: 1.3624478, Longitude: 103.888377
# Geocoded: 122 Cactus Rd -> Latitude: 1.3910267, Longitude: 103.8514797
# WARNING:root:Failed to geocode: 689D Woodlands Drive 75
# Geocoded: Tembeling Ln -> Latitude: 1.3139765, Longitude: 103.9010914
# Geocoded: 34 Jln Kechubong -> Latitude: 1.38561325, Longitude: 103.8761442235026
# Geocoded: Jln Rindu -> Latitude: 1.3453145, Longitude: 103.8770937
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: Little India -> Latitude: 1.30684265, Longitude: 103.84927355170905
# Geocoded: Lowland Rd -> Latitude: 1.360778, Longitude: 103.8839762
# Geocoded: 485 Dunman Rd -> Latitude: 1.3096473999999998, Longitude: 103.89339
# Geocoded: 57 Jln Pergam -> Latitude: 1.3458676, Longitude: 103.9619191
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# Geocoded: Taman Kembangan -> Latitude: 1.3245794, Longitude: 103.9136468
# Geocoded: 485 Dunman Rd -> Latitude: 1.3096473999999998, Longitude: 103.89339
# WARNING:root:Failed to geocode: 689D Woodlands Drive 75
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: Emerald Hill Rd -> Latitude: 1.3055189, Longitude: 103.8394459
# Geocoded: Loyang -> Latitude: 1.3753678, Longitude: 103.9772924
# WARNING:root:Failed to geocode: 163 Yung Ping Rd
# Geocoded: 18L Jln Paras -> Latitude: 1.32547195, Longitude: 103.91662945
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: 16A Duxton Hill -> Latitude: 1.2794164, Longitude: 103.8433026
# Geocoded: 22C Jln Naung -> Latitude: 1.3687658, Longitude: 103.8922785
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# WARNING:root:Failed to geocode: 689B Woodlands Drive 75
# WARNING:root:Failed to geocode: 5 Lor Ong Lye
# Geocoded: 72 Jln Gembira -> Latitude: 1.3320764, Longitude: 103.8796611
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: Tembeling Ln -> Latitude: 1.3139765, Longitude: 103.9010914
# WARNING:root:Failed to geocode: 689D Woodlands Drive 75
# WARNING:root:Failed to geocode: 689E Woodlands Drive 75
# Geocoded: Mayflower Ave -> Latitude: 1.3699195, Longitude: 103.8404698
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# WARNING:root:Failed to geocode: 3 to 57 Blair Road
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: 70B Bournemouth Rd -> Latitude: 1.3014776, Longitude: 103.8912028
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 73 Springleaf Cres -> Latitude: 1.4002732, Longitude: 103.8243465
# Geocoded: 22 Verde Grove -> Latitude: 1.39150795, Longitude: 103.7518
# WARNING:root:Failed to geocode: Singapore 678762
# Geocoded: 20A Meng Suan Rd -> Latitude: 1.4031457, Longitude: 103.81257463338162
# Geocoded: Simon Rd -> Latitude: 1.3614432, Longitude: 103.8858127
# Geocoded: Lowland Rd -> Latitude: 1.360778, Longitude: 103.8839762
# Geocoded: Loyang -> Latitude: 1.3753678, Longitude: 103.9772924
# Geocoded: Mayflower Ave -> Latitude: 1.3699195, Longitude: 103.8404698
# Geocoded: 1 Chu Lin Rd -> Latitude: 1.3577895, Longitude: 103.7606314
# Geocoded: Taman Kembangan -> Latitude: 1.3245794, Longitude: 103.9136468
# WARNING:root:Failed to geocode: 690D Woodlands Drive 75
# WARNING:root:Failed to geocode: 690D Woodlands Drive 75
# Geocoded: 34 Kheam Hock Rd -> Latitude: 1.3316026, Longitude: 103.8199813
# Geocoded: 112 Bukit Purmei Rd -> Latitude: 1.2744724, Longitude: 103.825486
# Geocoded: Tanglin Hill -> Latitude: 1.30213125, Longitude: 103.81736815186657
# Geocoded: 15 Jln Rengkam -> Latitude: 1.3624478, Longitude: 103.888377
# Geocoded: 15 Jln Rengkam -> Latitude: 1.3624478, Longitude: 103.888377
# Geocoded: Sembawang Rd -> Latitude: 1.4452947, Longitude: 103.823938
# Geocoded: Cashew Cres -> Latitude: 1.3709118, Longitude: 103.7696991
# WARNING:root:Failed to geocode: Tyrwhitt Rd & Petain Rd
# Geocoded: Geylang -> Latitude: 1.3181862, Longitude: 103.8870563
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: Serangoon Garden Way -> Latitude: 1.3633225, Longitude: 103.8704938
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: Sembawang Rd -> Latitude: 1.4452947, Longitude: 103.823938
# Geocoded: Tembeling Ln -> Latitude: 1.3139765, Longitude: 103.9010914
# Geocoded: Mayflower Ave -> Latitude: 1.3699195, Longitude: 103.8404698
# WARNING:root:Failed to geocode: Singapore 678762
# Geocoded: 585A Upper Changi Rd -> Latitude: 1.3347016, Longitude: 103.9513927
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# Geocoded: 1 Happy Ave N -> Latitude: 1.3298275, Longitude: 103.8801979
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# Geocoded: 35 Jln Lada Puteh -> Latitude: 1.3052187, Longitude: 103.8338777
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 8 Jln Gelenggang -> Latitude: 1.3730794, Longitude: 103.8301189658496
# WARNING:root:Failed to geocode: 689D Woodlands Drive 75
# WARNING:root:Failed to geocode: Singapore 678762
# WARNING:root:Failed to geocode: 688D Woodlands Drive 75
# Geocoded: 57 Jln Pergam -> Latitude: 1.3458676, Longitude: 103.9619191
# Geocoded: 57 Jln Pergam -> Latitude: 1.3458676, Longitude: 103.9619191
# WARNING:root:Failed to geocode: 3 to 57 Blair Road
# Geocoded: Sembawang Rd -> Latitude: 1.4452947, Longitude: 103.823938
# Geocoded: 22 Verde Grove -> Latitude: 1.39150795, Longitude: 103.7518
# Geocoded: 245 Orchard Blvd -> Latitude: 1.30230865, Longitude: 103.8249272581665
# WARNING:root:Failed to geocode: Singapore 678762
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 20A Meng Suan Rd -> Latitude: 1.4031457, Longitude: 103.81257463338162
# Geocoded: Singapore -> Latitude: 1.2899175, Longitude: 103.8519072
# Geocoded: 125 Frankel Ave -> Latitude: 1.3113556, Longitude: 103.9204831
# WARNING:root:Failed to geocode: 688F Woodlands Drive 75
# Geocoded: 95 Sophia Rd -> Latitude: 1.30205485, Longitude: 103.84685166989897
# WARNING:root:Failed to geocode: 689B Woodlands Drive 75
# Geocoded: 72 Jln Gembira -> Latitude: 1.3320764, Longitude: 103.8796611
# WARNING:root:Failed to geocode: 688E Woodlands Drive 75
# WARNING:root:Failed to geocode: 23 Terrasse Ln
# Geocoded: Tai Keng Gardens -> Latitude: 1.3463732, Longitude: 103.8859221
# Geocoded: Beach Rd -> Latitude: 1.2974463, Longitude: 103.856983
# Geocoded: Mariam Way -> Latitude: 1.3589568, Longitude: 103.9697391
# Geocoded: 50 Chempaka Kuning Link -> Latitude: 1.3324, Longitude: 103.9485953
# WARNING:root:Failed to geocode: 690f Woodlands Drive 75

# %%
# Geocoding for remaining address
property_full_address = pd.read_csv('address_list.csv')

# Define a custom function to replace None & Singapore with values from other DataFrame
def replace_full_address(row):
    if row['full_address'] is None or row['full_address'].lower() == 'singapore' or row['full_address'].lower() == 'singapore, central, 178957, singapore' :
        matching_row = property_full_address[property_full_address['address'] == row['address']]
        if not matching_row.empty:
            return matching_row.iloc[0]['geocoded_address']
    return row['full_address']

# Apply the custom function to update 'full_address' column
df['full_address'] = df.apply(replace_full_address, axis=1)

# %%
# Geocoding for address with 'Woodlands Drive'

# Define a function to update full_address
def update_full_address(row):
    if 'Woodlands Drive' in row['address'] and row['full_address'] == None:
        return row['address'] + ', Woodlands, Northwest, 730888, Singapore'
    return row['full_address']

# Apply the update_full_address function to the DataFrame
df['full_address'] = df.apply(update_full_address, axis=1)

# %%
# Remove all "Singapore" 
df['full_address'] = df['full_address'].apply(lambda x: ', '.join([str(part).strip() for part in str(x).split(', ') if part != 'Singapore']))

# Add ', Singapore' to the end of every row
df['full_address'] = df['full_address'] + ', Singapore'

# %% [markdown]
# ### Extracting Planning Areas

# %%
# Read the CSV file into a DataFrame
# This file is to map planning area based on subzone
subzone_planning_area = pd.read_csv('planning_area_subzone_list.csv')

# Create a dictionary mapping subzones to planning areas
subzone_to_planning_area = dict(zip(subzone_planning_area['Subzone'], subzone_planning_area['Planning_area']))

# %%
# Define the list of planning areas and regions
planning_areas = [
    "Ang Mo Kio","Bedok","Bishan","Boon Lay","Bukit Batok","Bukit Merah","Bukit Panjang","Bukit Timah","Central Water Catchment",
    "Changi","Changi Bay","Choa Chu Kang","Clementi","Downtown Core","Geylang","Hougang","Jurong East","Jurong West","Kallang",
    "Lim Chu Kang","Mandai","Marina East","Marina South","Marine Parade","Museum","Newton","North-Eastern Islands","Novena",
    "Orchard","Outram","Pasir Ris","Paya Lebar","Pioneer","Punggol","Queenstown","River Valley","Rochor","Seletar","Sembawang",
    "Seng Kang","Serangoon","Simpang","Singapore River","Southern Islands","Straits View","Sungei Kadut","Tampines","Tanglin",
    "Tengah","Toa Payoh","Tuas","Western Islands","Western Water Catchment","Woodlands","Yishun"
]


# Create empty columns for planning_area and region
df['planning_area'] = ""

# Define a function to extract planning_area and region
def extract_planning_area_and_region(address):
    # Split the address by ","
    address_parts = address.split(',')
    
    # Initialize variables to store planning area and region
    planning_area = ""
    
    # Iterate through the address parts
    for part in address_parts:
        part = part.strip()  # Remove leading/trailing spaces
        
        if part in planning_areas:
            planning_area = part
            break  # Exit the loop if planning area is found

    # If no planning area found, check for subzone and assign planning area based on the subzone
    if not planning_area:
        for part in address_parts:
            part = part.strip()
            if part in subzone_to_planning_area:
                planning_area = subzone_to_planning_area[part]
                break  # Exit the loop if subzone is found

    return planning_area

# Apply the function to extract values and populate the DataFrame
df['planning_area'] = df['full_address'].apply(extract_planning_area_and_region)

# %% [markdown]
# ### Extracting Region

# %%
# Dictionary mapping planning areas to regions
planning_area_to_region = {
    'Ang Mo Kio': 'North-East',
    'Bedok': 'East',
    'Bishan': 'Central',
    'Boon Lay': 'West',
    'Bukit Batok': 'West',
    'Bukit Merah': 'Central',
    'Bukit Panjang': 'West',
    'Bukit Timah': 'Central',
    'Central Water Catchment': 'North',
    'Changi': 'East',
    'Changi Bay': 'East',
    'Choa Chu Kang': 'West',
    'Clementi': 'West',
    'Downtown Core': 'Central',
    'Geylang': 'Central',
    'Hougang': 'North-East',
    'Jurong East': 'West',
    'Jurong West': 'West',
    'Kallang': 'Central',
    'Lim Chu Kang': 'North',
    'Mandai': 'North',
    'Marina East': 'Central',
    'Marina South': 'Central',
    'Marine Parade': 'Central',
    'Museum': 'Central',
    'Newton': 'Central',
    'North-Eastern Islands': 'North-East',
    'Novena': 'Central',
    'Orchard': 'Central',
    'Outram': 'Central',
    'Pasir Ris': 'East',
    'Paya Lebar': 'East',
    'Pioneer': 'West',
    'Punggol': 'North-East',
    'Queenstown': 'Central',
    'River Valley': 'Central',
    'Rochor': 'Central',
    'Seletar': 'North-East',
    'Sembawang': 'North',
    'Seng Kang': 'North-East',
    'Serangoon': 'North-East',
    'Simpang': 'North',
    'Singapore River': 'Central',
    'Southern Islands': 'Central',
    'Straits View': 'Central',
    'Sungei Kadut': 'North',
    'Tampines': 'East',
    'Tanglin': 'Central',
    'Tengah': 'West',
    'Toa Payoh': 'Central',
    'Tuas': 'West',
    'Western Islands': 'West',
    'Western Water Catchment': 'West',
    'Woodlands': 'North',
    'Yishun': 'North'
}
# Assign regions based on the planning_area column
df['region'] = df['planning_area'].map(planning_area_to_region)

# %% [markdown]
# ### Extracting Nearest MRT Station, Distance & Time to the nearest station

# %%
mrt = pd.read_csv('MRT Stations.csv')

# %%
# Function to calculate Haversine distance between two sets of coordinates
def haversine(lat1, lon1, lat2, lon2):
    # Radius of the Earth in kilometers
    radius = 6371.0
    
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = radius * c
    
    return distance

# Function to find the nearest MRT station and its Haversine distance
def find_nearest_mrt(row):
    address_lat = row['latitude']
    address_lon = row['longitude']
    
    min_distance = float('inf')
    nearest_station = ''
    
    for _, mrt_row in mrt.iterrows():
        mrt_lat = mrt_row['latitude']
        mrt_lon = mrt_row['longitude']
        
        distance = haversine(address_lat, address_lon, mrt_lat, mrt_lon)
        
        if distance < min_distance:
            min_distance = distance
            nearest_station = mrt_row['STN_NAME']
    
    return nearest_station, min_distance

# Apply the function to your 'df' DataFrame
df[['Nearest MRT Station', 'Distance to Nearest MRT']] = df.apply(find_nearest_mrt, axis=1, result_type='expand')

# %%
# Define walking speed in km/h
walking_speed_kmph = 5

# Function to calculate walking time
def calculate_walking_time(row):
    # Get the walking distance (in kilometers)
    walking_distance_km = row['Distance to Nearest MRT']

    # Calculate walking time (in hours)
    walking_time_hours = walking_distance_km / walking_speed_kmph

    # Convert to minutes if needed
    walking_time_minutes = walking_time_hours * 60

    return walking_time_minutes

# Apply the function to your 'df' DataFrame and create a new column for walking time
df['Walking Time to Nearest MRT (minutes)'] = df.apply(calculate_walking_time, axis=1)

# %%
# Perform the join based on the "Nearest MRT Station" column
df = df.merge(mrt[['STN_NAME', 'latitude', 'longitude']], left_on='Nearest MRT Station', right_on='STN_NAME', how='left')

# Drop the duplicate "STN_NAME" column if needed
df.drop(columns=['STN_NAME','nearest_mrt','time_to_nearest_mrt'], inplace=True)

# %% [markdown]
# ### Final Cleanup

# %%
# Define a dictionary to map old column names to new column names
column_mapping = {'latitude_x': 'latitude', 'longitude_x': 'longitude', 'latitude_y': 'latitude_mrt'
                  ,'longitude_y':'longitude_mrt','Distance to Nearest MRT':'Distance_to_Nearest_MRT_km'
                  ,'Walking Time to Nearest MRT (minutes)':'Walking_Time_to_Nearest_MRT_min'
                  ,'room_size':'room_size_sqft','Nearest MRT Station':'Nearest_MRT_Station'}

# Use the .rename() method to rename columns
df = df.rename(columns=column_mapping)

# Define the desired order of columns
desired_order = ['address', 'full_address', 'latitude', 'longitude', 'planning_area', 'region', 'Nearest_MRT_Station'
                 , 'latitude_mrt', 'longitude_mrt', 'Distance_to_Nearest_MRT_km', 'Walking_Time_to_Nearest_MRT_min'
                 , 'price', 'unit_type', 'room_type', 'room_size_sqft', 'status', 'updated_date', 'link']

# Select the columns in the desired order
df = df[desired_order]

# %%
df.to_csv('Rental_data_final.csv', index=False)
